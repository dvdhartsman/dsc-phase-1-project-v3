# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("data/Aviation_Data.csv")
# Out:
# /Users/samalainabayeva/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (6,7,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
pd.options.display.max_columns = 50

# %%
df.shape
# Out:
# (90348, 31)

# %%
df_clean.shape
# Out:
# (88889, 31)

# %%
90348 - 88889
# Out:
# 1459

# %%
df.describe()
# Out:
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count       82805.000000          77488.000000            76379.000000
# mean            1.146585              0.647855                0.279881
# std             0.446510              5.485960                1.544084
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# 75%             1.000000              0.000000                0.000000
# max             8.000000            349.000000              161.000000
#
#        Total.Minor.Injuries  Total.Uninjured
# count          76956.000000     82977.000000
# mean               0.357061         5.325440
# std                2.235625        27.913634
# min                0.000000         0.000000
# 25%                0.000000         0.000000
# 50%                0.000000         1.000000
# ...

# %%
df.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country Latitude Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States      NaN       NaN          NaN
# 1   BRIDGEPORT, CA  United States      NaN       NaN          NaN
# 2    Saltville, VA  United States  36.9222  -81.8781          NaN
# 3       EUREKA, CA  United States      NaN       NaN          NaN
# 4       Canton, OH  United States      NaN       NaN          NaN
#
#   Airport.Name Injury.Severity Aircraft.damage Aircraft.Category  \
# 0          NaN        Fatal(2)       Destroyed               NaN
# ...

# %% [markdown]
# ### We will drop values from the data set who's accident type is not either Accident or Incident

# %%
df_clean = df.loc[(df["Investigation.Type"] == "Accident") | (df["Investigation.Type"] == "Incident")]

# %% [markdown]
# ### Next, we dropped Latitude and Longitude columns for having too much missing data, likely irrelevant

# %%
df_clean.drop(columns=["Latitude", "Longitude"], inplace=True)

# %%
df_clean.shape
# Out:
# (88889, 29)

# %%
df_clean.isna().sum()
# Out:
# Event.Id                      0
# Investigation.Type            0
# Accident.Number               0
# Event.Date                    0
# Location                     52
# Country                     226
# Airport.Code              38640
# Airport.Name              36099
# Injury.Severity            1000
# Aircraft.damage            3194
# Aircraft.Category         56602
# Registration.Number        1317
# Make                         63
# Model                        92
# Amateur.Built               102
# Number.of.Engines          6084
# Engine.Type                7077
# FAR.Description           56866
# Schedule                  76307
# Purpose.of.flight          6192
# Air.carrier               72241
# Total.Fatal.Injuries      11401
# Total.Serious.Injuries    12510
# Total.Minor.Injuries      11933
# Total.Uninjured            5912
# Weather.Condition          4492
# Broad.phase.of.flight     27165
# Report.Status              6381
# Publication.Date          15230
# ...

# %%
df_clean["Location"].str.upper().value_counts()[:20]
# Out:
# ANCHORAGE, AK      548
# MIAMI, FL          275
# HOUSTON, TX        271
# ALBUQUERQUE, NM    265
# CHICAGO, IL        256
# FAIRBANKS, AK      246
# PHOENIX, AZ        224
# TUCSON, AZ         196
# DENVER, CO         196
# ATLANTA, GA        189
# SAN DIEGO, CA      177
# RENO, NV           177
# LAS VEGAS, NV      175
# TALKEETNA, AK      171
# PALMER, AK         163
# ORLANDO, FL        163
# ENGLEWOOD, CO      159
# SAN ANTONIO, TX    151
# MESA, AZ           149
# CHANDLER, AZ       148
# Name: Location, dtype: int64

# %%
df_clean[df_clean["Location"].isna() == True]["Investigation.Type"].value_counts()
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date Location  \
# 4239   20001214X42513           Accident      LAX83LAMS4  1983-03-29      NaN
# 5726   20001214X44103           Accident      DCA83RA001  1983-08-04      NaN
# 7948   20001214X39337           Incident      MIA84IA140  1984-04-14      NaN
# 10546  20001214X41859           Accident      MIA85LAMS1  1984-12-23      NaN
# 12527  20001214X37399           Accident      CHI85FAMS3  1985-08-03      NaN
# 22058  20001213X27404           Accident      DCA89WA019  1988-12-16      NaN
# 24214  20001213X29712           Accident      SEA90FAMS1  1989-10-06      NaN
# 26295  20001212X24088           Accident      MIA90WA175  1990-08-07      NaN
# 26881  20001212X24491           Accident      LAX91LA013  1990-10-22      NaN
# 27261  20001212X16361           Accident      MIA91WA066  1991-01-14      NaN
# 29763  20001211X14040           Accident      MIA92WA066  1992-01-23      NaN
# ...

# %% [markdown]
# ### DAMAGE TYPES

# %%
df_clean.loc[:,["Total.Fatal.Injuries", "Total.Serious.Injuries", "Total.Minor.Injuries"]].sum()
# Out:
# Total.Fatal.Injuries      50201.0
# Total.Serious.Injuries    21377.0
# Total.Minor.Injuries      27478.0
# dtype: float64

# %% [markdown]
# ### For unknown: 56 fatal, 16 serious, 25 Minor injuries

# %%
df_clean[df_clean["Aircraft.damage"] == "Unknown"]["Total.Fatal.Injuries"].sum()
# Out:
# 56.0

# %%
df["Aircraft.damage"].value_counts(normalize=True)
# Out:
# Substantial    0.748562
# Destroyed      0.217317
# Minor          0.032732
# Unknown        0.001389
# Name: Aircraft.damage, dtype: float64

# %% [markdown]
# ### DAMAGE and WEATHER

# %%
df[df["Aircraft.damage"] == "Destroyed"]["Weather.Condition"].value_counts(normalize=True)
# Out:
# VMC    0.780253
# IMC    0.189367
# UNK    0.026243
# Unk    0.004138
# Name: Weather.Condition, dtype: float64

# %%
df[df["Aircraft.damage"] == "Substantial"]["Weather.Condition"].value_counts(normalize=True)
# Out:
# VMC    0.957991
# IMC    0.036161
# UNK    0.004166
# Unk    0.001682
# Name: Weather.Condition, dtype: float64

# %%
df[df["Aircraft.damage"] == "Minor"]["Weather.Condition"].value_counts(normalize=True)
# Out:
# VMC    0.882823
# IMC    0.074123
# UNK    0.030626
# Unk    0.012428
# Name: Weather.Condition, dtype: float64

# %% [markdown]
# ### Weather TYPES

# %%
df["Weather.Condition"].value_counts(normalize=True)
# Out:
# VMC    0.915945
# IMC    0.070808
# UNK    0.010143
# Unk    0.003104
# Name: Weather.Condition, dtype: float64

# %%
df.isna().sum()
# Out:
# Event.Id                   1459
# Investigation.Type            0
# Accident.Number            1459
# Event.Date                 1459
# Location                   1511
# Country                    1685
# Latitude                  55966
# Longitude                 55975
# Airport.Code              40099
# Airport.Name              37558
# Injury.Severity            2459
# Aircraft.damage            4653
# Aircraft.Category         58061
# Registration.Number        2776
# Make                       1522
# Model                      1551
# Amateur.Built              1561
# Number.of.Engines          7543
# Engine.Type                8536
# FAR.Description           58325
# Schedule                  77766
# Purpose.of.flight          7651
# Air.carrier               73700
# Total.Fatal.Injuries      12860
# Total.Serious.Injuries    13969
# Total.Minor.Injuries      13392
# Total.Uninjured            7371
# Weather.Condition          5951
# Broad.phase.of.flight     28624
# ...

# %%
df_clean = df.loc[(df["Investigation.Type"] == "Accident") | (df["Investigation.Type"] == "Incident")]
df_clean.isna().sum()
# Out:
# Event.Id                      0
# Investigation.Type            0
# Accident.Number               0
# Event.Date                    0
# Location                     52
# Country                     226
# Latitude                  54507
# Longitude                 54516
# Airport.Code              38640
# Airport.Name              36099
# Injury.Severity            1000
# Aircraft.damage            3194
# Aircraft.Category         56602
# Registration.Number        1317
# Make                         63
# Model                        92
# Amateur.Built               102
# Number.of.Engines          6084
# Engine.Type                7077
# FAR.Description           56866
# Schedule                  76307
# Purpose.of.flight          6192
# Air.carrier               72241
# Total.Fatal.Injuries      11401
# Total.Serious.Injuries    12510
# Total.Minor.Injuries      11933
# Total.Uninjured            5912
# Weather.Condition          4492
# Broad.phase.of.flight     27165
# ...

# %%
df_clean.isna().sum()
# Out:
# Event.Id                      0
# Investigation.Type            0
# Accident.Number               0
# Event.Date                    0
# Location                     52
# Country                     226
# Latitude                  54507
# Longitude                 54516
# Airport.Code              38640
# Airport.Name              36099
# Injury.Severity            1000
# Aircraft.damage            3194
# Aircraft.Category         56602
# Registration.Number        1317
# Make                         63
# Model                        92
# Amateur.Built               102
# Number.of.Engines          6084
# Engine.Type                7077
# FAR.Description           56866
# Schedule                  76307
# Purpose.of.flight          6192
# Air.carrier               72241
# Total.Fatal.Injuries      11401
# Total.Serious.Injuries    12510
# Total.Minor.Injuries      11933
# Total.Uninjured            5912
# Weather.Condition          4492
# Broad.phase.of.flight     27165
# ...

# %%
df_drop = df_clean.drop(columns=["Latitude", "Longitude"])
df_drop.isna().sum()
# Out:
# Event.Id                      0
# Investigation.Type            0
# Accident.Number               0
# Event.Date                    0
# Location                     52
# Country                     226
# Airport.Code              38640
# Airport.Name              36099
# Injury.Severity            1000
# Aircraft.damage            3194
# Aircraft.Category         56602
# Registration.Number        1317
# Make                         63
# Model                        92
# Amateur.Built               102
# Number.of.Engines          6084
# Engine.Type                7077
# FAR.Description           56866
# Schedule                  76307
# Purpose.of.flight          6192
# Air.carrier               72241
# Total.Fatal.Injuries      11401
# Total.Serious.Injuries    12510
# Total.Minor.Injuries      11933
# Total.Uninjured            5912
# Weather.Condition          4492
# Broad.phase.of.flight     27165
# Report.Status              6381
# Publication.Date          15230
# ...

# %%
df["Latitude"].notnull().sum()
# Out:
# 34382

# %%
df["Latitude"].describe()
# Out:
# count       34382
# unique      25592
# top       332739N
# freq           19
# Name: Latitude, dtype: object

# %%
df["Longitude"].notnull().sum()
# Out:
# 34373

# %%
df["Longitude"].describe()
# Out:
# count        34373
# unique       27156
# top       0112457W
# freq            24
# Name: Longitude, dtype: object

# %%
df_clean.isna().sum()
# Out:
# Event.Id                      0
# Investigation.Type            0
# Accident.Number               0
# Event.Date                    0
# Location                     52
# Country                     226
# Latitude                  54507
# Longitude                 54516
# Airport.Code              38640
# Airport.Name              36099
# Injury.Severity            1000
# Aircraft.damage            3194
# Aircraft.Category         56602
# Registration.Number        1317
# Make                         63
# Model                        92
# Amateur.Built               102
# Number.of.Engines          6084
# Engine.Type                7077
# FAR.Description           56866
# Schedule                  76307
# Purpose.of.flight          6192
# Air.carrier               72241
# Total.Fatal.Injuries      11401
# Total.Serious.Injuries    12510
# Total.Minor.Injuries      11933
# Total.Uninjured            5912
# Weather.Condition          4492
# Broad.phase.of.flight     27165
# ...

# %%
df_clean[df_clean["Location"].isna()]
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date Location  \
# 4239   20001214X42513           Accident      LAX83LAMS4  1983-03-29      NaN
# 5726   20001214X44103           Accident      DCA83RA001  1983-08-04      NaN
# 7948   20001214X39337           Incident      MIA84IA140  1984-04-14      NaN
# 10546  20001214X41859           Accident      MIA85LAMS1  1984-12-23      NaN
# 12527  20001214X37399           Accident      CHI85FAMS3  1985-08-03      NaN
# 22058  20001213X27404           Accident      DCA89WA019  1988-12-16      NaN
# 24214  20001213X29712           Accident      SEA90FAMS1  1989-10-06      NaN
# 26295  20001212X24088           Accident      MIA90WA175  1990-08-07      NaN
# 26881  20001212X24491           Accident      LAX91LA013  1990-10-22      NaN
# 27261  20001212X16361           Accident      MIA91WA066  1991-01-14      NaN
# 29763  20001211X14040           Accident      MIA92WA066  1992-01-23      NaN
# ...

# %%
other_Report_Status = df_clean[df_clean["Report.Status"] != "Probable Cause"]

# %% [markdown]
# ### 61754 entries where the report was filed for probable cause!

# %%
other_Report_Status["Report.Status"].unique()
# Out:
# array(['Factual', 'Foreign', 'Preliminary', ...,
#        'The pilot did not ensure adequate clearance from construction vehicles during taxi.',
#        'The pilot\x92s failure to secure the magneto switch before attempting to hand rotate the engine which resulted in an inadvertent engine start, a runaway airplane, and subsequent impact with parked airplanes. Contributing to the accident was the failure to properly secure the airplane with chocks.',
#        'The pilot\x92s loss of control due to a wind gust during landing.'],
#       dtype=object)

# %% [markdown]
# ### SMALL AIRCRAFT/PILOT ERROR, can PROBABLY BE DROPPED AND SEPARATED FOR ANALYSIS!!!!

# %%
long_form = df_clean[df_clean["Report.Status"].notnull()]

# %%
pilot_error_reports = long_form.loc[long_form["Report.Status"].str.contains("pilot")]["Report.Status"]

# %%
pilot_error = long_form.loc[long_form["Report.Status"].str.contains("pilot")]

# %%
pilot_error.head()
pilot_error.reset_index(inplace=True)

# %%
pilot_error["Make"] = pilot_error["Make"].str.upper()
# Out:
# <ipython-input-23-7b93352e6355>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pilot_error["Make"] = pilot_error["Make"].str.upper()

# %% [markdown]
# ### The overwhelming majority of pilot errors are in small aircraft

# %% [markdown]
# ### Top 5 represent 50% of pilot errors, all small planes, Bell no longer made, was WWII plane

# %%
pilot_error["Make"].value_counts(normalize=False)[:10]
# Out:
# CESSNA                 3638
# PIPER                  2056
# BEECH                   667
# BELL                    272
# MOONEY                  181
# AIR TRACTOR INC         145
# ROBINSON HELICOPTER     142
# MAULE                   128
# BELLANCA                125
# AERONCA                 125
# Name: Make, dtype: int64

# %% [markdown]
# ### 95% of accidents were in fair weather

# %%
pilot_error["Weather.Condition"].value_counts(normalize=True)
# Out:
# VMC    0.946893
# IMC    0.050048
# Unk    0.003058
# Name: Weather.Condition, dtype: float64

# %%
pilot_error["Report.Status"]
# Out:
# 0         The departing pilot's inadequate visual lookout.
# 1        The pilot's failure to maintain directional co...
# 2        the student pilot's premature flare resulting ...
# 3        The pilot's inadequate compensation for wind c...
# 4        The pilot's failure to follow the checklist an...
#                                ...
# 13415    The pilots failure to maintain adequate airsp...
# 13416    The pilots failure to maintain control of the...
# 13417    The pilot did not ensure adequate clearance fr...
# 13418    The pilots failure to secure the magneto swit...
# 13419    The pilots loss of control due to a wind gust...
# Name: Report.Status, Length: 13420, dtype: object

# %%
for i in range(5):
    print(pilot_error.loc[i, "Report.Status"], pilot_error.loc[i, "Weather.Condition"])
# Out:
# The departing pilot's inadequate visual lookout. VMC
# The pilot's failure to maintain directional control.  A contributing factor was the prevailing crosswind. VMC
# the student pilot's premature flare resulting in the loss of aircraft control. VMC
# The pilot's inadequate compensation for wind conditions.  A factor in the accident was the wind gust. VMC
# The pilot's failure to follow the checklist and failure to achieve the proper touchdown point during a forced landing. Contributing to the accident was a loss of engine power due to a cracked No. 4 top sparkplug insulator, resulting in pre-ignition/detonation and the failure of the No. 2 connecting rod cap due to evacuation of the oil supply. VMC
