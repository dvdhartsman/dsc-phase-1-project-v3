# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("data/Aviation_Data.csv")
# Out:
# /Users/samalainabayeva/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (6,7,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ### PRELIMINARY EXPLORATION

# %%
df.shape
# Out:
# (90348, 31)

# %%
df.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Event.Id                   object
# Investigation.Type         object
# Accident.Number            object
# Event.Date                 object
# Location                   object
# Country                    object
# Latitude                   object
# Longitude                  object
# Airport.Code               object
# Airport.Name               object
# Injury.Severity            object
# Aircraft.damage            object
# Aircraft.Category          object
# Registration.Number        object
# Make                       object
# Model                      object
# Amateur.Built              object
# Number.of.Engines         float64
# Engine.Type                object
# FAR.Description            object
# Schedule                   object
# Purpose.of.flight          object
# Air.carrier                object
# Total.Fatal.Injuries      float64
# Total.Serious.Injuries    float64
# Total.Minor.Injuries      float64
# Total.Uninjured           float64
# ...

# %%
df.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country Latitude Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States      NaN       NaN          NaN
# 1   BRIDGEPORT, CA  United States      NaN       NaN          NaN
# 2    Saltville, VA  United States  36.9222  -81.8781          NaN
# 3       EUREKA, CA  United States      NaN       NaN          NaN
# 4       Canton, OH  United States      NaN       NaN          NaN
#
#   Airport.Name Injury.Severity Aircraft.damage Aircraft.Category  \
# 0          NaN        Fatal(2)       Destroyed               NaN
# ...

# %% [markdown]
# ### Weather Values: UNK | IMC | VMC| Unk (unknown, instrument meterological conditions, visual met cond.)

# %% [markdown]
# ### VMC - the pilot can navigate by sight --- IMC - the pilot must rely on Instruments to navigate

# %%
df["Weather.Condition"].unique()
# Out:
# array(['UNK', 'IMC', 'VMC', nan, 'Unk'], dtype=object)

# %% [markdown]
# ### INVESTIGATION TYPES ARE ACCIDENTS AND INCIDENTS!!!

# %%
df["Investigation.Type"].value_counts()
# Out:
# Accident      85015
# Incident       3874
# 25-09-2020      702
# 26-09-2020       60
# 02-02-2021       39
# 20-08-2021       37
# 20-09-2021       33
# 03-12-2020       29
# 05-05-2021       29
# 06-05-2021       24
# 24-08-2021       22
# 14-06-2022       21
# 19-11-2020       20
# 27-05-2021       18
# 28-01-2021       18
# 13-10-2022       17
# 19-10-2021       17
# 24-06-2021       15
# 16-11-2021       15
# 01-11-2022       14
# 01-07-2022       14
# 06-10-2022       14
# 08-09-2022       13
# 17-12-2021       13
# 13-07-2022       13
# 05-07-2022       13
# 22-09-2022       13
# 26-08-2021       13
# 20-10-2021       12
# 25-05-2021       11
# 10-06-2021       10
# 01-09-2022       10
# 15-07-2021       10
# 12-08-2022       10
# 16-07-2021       10
# 15-10-2021        9
# 14-12-2021        8
# 23-09-2022        8
# 20-05-2021        8
# 02-12-2022        8
# 22-06-2022        8
# 20-07-2022        8
# 29-01-2021        8
# 22-09-2021        8
# 29-09-2021        8
# ...

# %%
pd.options.display.max_columns = 50

# %%
fatality = df.loc[df['Injury.Severity'] != "Non-Fatal"]
fatality['Total.Fatal.Injuries'].sum()
# Out:
# 50201.0

# %% [markdown]
# ### This is equal to the sum of all other fatality categories  (50201)
# ### (accident_deaths["Total.Fatal.Injuries"].sum() + incident_deaths["Total.Fatal.Injuries"].sum())

# %%
df['Injury.Severity'].value_counts()
# Out:
# Non-Fatal     67357
# Fatal(1)       6167
# Fatal          5262
# Fatal(2)       3711
# Incident       2219
#               ...
# Fatal(78)         1
# Fatal(189)        1
# Fatal(56)         1
# Fatal(45)         1
# Fatal(73)         1
# Name: Injury.Severity, Length: 109, dtype: int64

# %%
df['Injury.Severity']
# Out:
# 0         Fatal(2)
# 1         Fatal(4)
# 2         Fatal(3)
# 3         Fatal(2)
# 4         Fatal(1)
#            ...
# 90343        Minor
# 90344          NaN
# 90345    Non-Fatal
# 90346          NaN
# 90347        Minor
# Name: Injury.Severity, Length: 90348, dtype: object

# %% [markdown]
# ### INCIDENTS --------------

# %%
incidents = df.loc[df["Investigation.Type"] == "Incident"]
incidents.shape
# Out:
# (3874, 31)

# %%
incidents.isna().sum()
# Out:
# Event.Id                     0
# Investigation.Type           0
# Accident.Number              0
# Event.Date                   0
# Location                    12
# Country                     20
# Latitude                  2890
# Longitude                 2890
# Airport.Code              1919
# Airport.Name              1843
# Injury.Severity            673
# Aircraft.damage           1734
# Aircraft.Category         2122
# Registration.Number        275
# Make                        27
# Model                       32
# Amateur.Built               44
# Number.of.Engines         1184
# Engine.Type               1236
# FAR.Description           2219
# Schedule                  1396
# Purpose.of.flight         1865
# Air.carrier               1898
# Total.Fatal.Injuries       645
# Total.Serious.Injuries     647
# Total.Minor.Injuries       624
# Total.Uninjured            144
# Weather.Condition         1359
# Broad.phase.of.flight     1956
# Report.Status             1145
# ...

# %%
incidents[["Total.Fatal.Injuries", "Total.Serious.Injuries", "Total.Minor.Injuries", "Total.Uninjured"]].sum()
# Out:
# Total.Fatal.Injuries          22.0
# Total.Serious.Injuries       306.0
# Total.Minor.Injuries        1182.0
# Total.Uninjured           186915.0
# dtype: float64

# %% [markdown]
# ### INCIDENTS WITH DEATHS

# %%
incident_deaths = incidents.loc[incidents["Total.Fatal.Injuries"] >= 1] 
# 1 death per flight each, totaling 17, one with 3 dead, one with 2 dead

# %%
incident_deaths.shape
# Out:
# (19, 31)

# %%
incident_deaths
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 506    20020917X02477           Incident      MKC82IA042  1982-03-08
# 7831   20001214X38954           Incident      ATL84IA137  1984-03-30
# 9666   20001214X41145           Incident      MIA84IA247  1984-09-04
# 11154  20001214X35862           Incident      CHI85IA145  1985-03-21
# 12325  20001214X37022           Incident      CHI85IA296  1985-07-17
# 16853  20001213X30217           Incident      DEN87IA058  1987-02-18
# 17122  20001213X30413           Incident      CHI87IA110  1987-03-29
# 20504  20001213X25877           Incident      BFO88IA057  1988-06-07
# 30312  20001211X14639           Incident      DEN92IA050  1992-05-04
# 30972  20001211X15247           Incident      SEA92IA164  1992-07-26
# 36980  20001207X03112           Incident      FTW95IA148  1995-03-29
# 39187  20001208X05448           Incident      MIA96IA094  1996-03-06
# 45232  20001211X11420           Incident      FTW99IA024  1998-11-10
# ...

# %%
incident_deaths.describe()
# Out:
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count          17.000000             19.000000                    14.0
# mean            1.647059              1.157895                     0.0
# std             0.785905              0.501460                     0.0
# min             1.000000              1.000000                     0.0
# 25%             1.000000              1.000000                     0.0
# 50%             2.000000              1.000000                     0.0
# 75%             2.000000              1.000000                     0.0
# max             4.000000              3.000000                     0.0
#
#        Total.Minor.Injuries  Total.Uninjured
# count             15.000000        16.000000
# mean               0.200000        13.937500
# std                0.774597        26.891061
# min                0.000000         0.000000
# 25%                0.000000         1.000000
# 50%                0.000000         1.500000
# ...

# %%
incidents[["Total.Fatal.Injuries", "Total.Serious.Injuries", "Total.Minor.Injuries"]].sum()
# Out:
# Total.Fatal.Injuries        22.0
# Total.Serious.Injuries     306.0
# Total.Minor.Injuries      1182.0
# dtype: float64

# %%
plot_data = incident_deaths[["Total.Fatal.Injuries", "Total.Serious.Injuries", "Total.Minor.Injuries"]]


fig, ax = plt.subplots(figsize=(12, 8))
ax.set_ylim(0, 1200)
ax.set_ylabel("People")
ax.set_xlabel("Injury Category")
ax.bar(x=["Fatal", "Serious", "Minor"], height = [22, 306, 1182]);

# %% [markdown]
# ### INCIDENTS WITH NON-LETHAL INJURIES

# %%
incident_injuries = incidents.loc[incidents["Total.Fatal.Injuries"] < 1][["Total.Fatal.Injuries", "Total.Serious.Injuries", "Total.Minor.Injuries", "Total.Uninjured"]]

# %%
total_injuries = incident_injuries.sum()

# %%
incident_injuries.shape
# Out:
# (3210, 4)

# %%
incident_injuries.describe()
# Out:
#        Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  \
# count                3210.0             3210.000000           3210.000000
# mean                    0.0                0.094393              0.231776
# std                     0.0                1.805466              1.868167
# min                     0.0                0.000000              0.000000
# 25%                     0.0                0.000000              0.000000
# 50%                     0.0                0.000000              0.000000
# 75%                     0.0                0.000000              0.000000
# max                     0.0               88.000000             42.000000
#
#        Total.Uninjured
# count      3210.000000
# mean         48.531464
# std          81.854387
# min           0.000000
# 25%           1.000000
# 50%           4.000000
# 75%          73.000000
# max         528.000000

# %% [markdown]
# ### ACCIDENTS DATA -----------------

# %%
accidents = df.loc[df["Investigation.Type"] == "Accident"]

# %%
accidents.shape
# Out:
# (85015, 31)

# %%
accidents = df.loc[df["Investigation.Type"] == "Accident"]
accidents[["Total.Fatal.Injuries", "Total.Serious.Injuries", "Total.Minor.Injuries", "Total.Uninjured"]].sum()
# Out:
# Total.Fatal.Injuries       50179.0
# Total.Serious.Injuries     21071.0
# Total.Minor.Injuries       26296.0
# Total.Uninjured           254974.0
# dtype: float64

# %%
(accident_deaths["Total.Fatal.Injuries"].sum() + incident_deaths["Total.Fatal.Injuries"].sum())
# Out:
# 50201.0

# %% [markdown]
# ### Accident Deaths ----------------

# %%
accident_deaths = accidents.loc[accidents["Total.Fatal.Injuries"] >= 1]

# %%
accident_deaths["Total.Fatal.Injuries"].describe()
# Out:
# count    17794.000000
# mean         2.819996
# std         11.177558
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max        349.000000
# Name: Total.Fatal.Injuries, dtype: float64

# %% [markdown]
# ### INVESTIGATION DATES, Not ACCIDENTS/INCIDENTS

# %%
misc = df.loc[(df["Investigation.Type"] != "Accident") & (df["Investigation.Type"] != "Incident")]

# %%
misc.notna().sum()
# Out:
# Event.Id                     0
# Investigation.Type        1459
# Accident.Number              0
# Event.Date                   0
# Location                     0
# Country                      0
# Latitude                     0
# Longitude                    0
# Airport.Code                 0
# Airport.Name                 0
# Injury.Severity              0
# Aircraft.damage              0
# Aircraft.Category            0
# Registration.Number          0
# Make                         0
# Model                        0
# Amateur.Built                0
# Number.of.Engines            0
# Engine.Type                  0
# FAR.Description              0
# Schedule                     0
# Purpose.of.flight            0
# Air.carrier                  0
# Total.Fatal.Injuries         0
# Total.Serious.Injuries       0
# Total.Minor.Injuries         0
# Total.Uninjured              0
# Weather.Condition            0
# Broad.phase.of.flight        0
# Report.Status                0
# ...

# %% [markdown]
# ### All of this Data Appears useless......

# %%
###null_set = misc.drop(axis= 1, columns=["Investigation.Type"], inplace=True)
# Out:
# /Users/samalainabayeva/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
misc.notnull().sum()
# Out:
# Event.Id                  0
# Accident.Number           0
# Event.Date                0
# Location                  0
# Country                   0
# Latitude                  0
# Longitude                 0
# Airport.Code              0
# Airport.Name              0
# Injury.Severity           0
# Aircraft.damage           0
# Aircraft.Category         0
# Registration.Number       0
# Make                      0
# Model                     0
# Amateur.Built             0
# Number.of.Engines         0
# Engine.Type               0
# FAR.Description           0
# Schedule                  0
# Purpose.of.flight         0
# Air.carrier               0
# Total.Fatal.Injuries      0
# Total.Serious.Injuries    0
# Total.Minor.Injuries      0
# Total.Uninjured           0
# Weather.Condition         0
# Broad.phase.of.flight     0
# Report.Status             0
# Publication.Date          0
# dtype: int64

# %%
df_clean = df.loc[(df["Investigation.Type"] == "Accident") | (df["Investigation.Type"] == "Incident")]

# %%
df_clean.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country Latitude Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States      NaN       NaN          NaN
# 1   BRIDGEPORT, CA  United States      NaN       NaN          NaN
# 2    Saltville, VA  United States  36.9222  -81.8781          NaN
# 3       EUREKA, CA  United States      NaN       NaN          NaN
# 4       Canton, OH  United States      NaN       NaN          NaN
#
#   Airport.Name Injury.Severity Aircraft.damage Aircraft.Category  \
# 0          NaN        Fatal(2)       Destroyed               NaN
# ...

# %%
df_clean
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 90343  20221227106491           Accident      ERA23LA093  2022-12-26
# 90344  20221227106494           Accident      ERA23LA095  2022-12-26
# 90345  20221227106497           Accident      WPR23LA075  2022-12-26
# 90346  20221227106498           Accident      WPR23LA076  2022-12-26
# 90347  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               Location        Country Latitude Longitude Airport.Code  \
# ...

# %% [markdown]
# ### MAKING ALL LOCATIONS UPPER CASE....

# %%
df_clean["Location"] = df_clean['Location'].str.upper()
# Out:
# <ipython-input-246-c09b0009751d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["Location"] = df_clean['Location'].str.upper()

# %%
df_clean["Location"].describe()
# Out:
# count             88837
# unique            21978
# top       ANCHORAGE, AK
# freq                548
# Name: Location, dtype: object

# %%
df_clean.loc[df_clean['Location'].isna()]["Total.Fatal.Injuries"].sum()
# Out:
# 147.0

# %% [markdown]
# ### Need to keep Data where location is null
